# %% [markdown]
# <a href="https://colab.research.google.com/github/JUANES31081/PORTAFOLIO_/blob/main/Clasificacion_perritos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Creando carpetas para las categorias
# !mkdir pug
# !mkdir beagle
# !mkdir otros

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !cp '/content/drive/MyDrive/ZIPS/BEAGLE.zip' '/content/beagle'
# !cp '/content/drive/MyDrive/ZIPS/PUG.zip' '/content/pug'
# !cp '/content/drive/MyDrive/ZIPS/OTROS.zip' '/content/otros'

# %%
#descomprimiendo en ambas carpetas

# %cd beagle
# !unzip BEAGLE.zip

# %cd ..

# %cd pug
# !unzip PUG.zip

# %cd ..

# %cd otros
# !unzip OTROS.zip

# %cd ..
# Out:
# /content/beagle
# Archive:  BEAGLE.zip
#   inflating: beagle_1.jpg
#   inflating: beagle_10.jpg
#   inflating: beagle_100.jpg
#   inflating: beagle_101.jpg
#   inflating: beagle_102.jpg
#   inflating: beagle_103.jpg
#   inflating: beagle_104.jpg
#   inflating: beagle_105.jpg
#   inflating: beagle_107.jpg
#   inflating: beagle_108.jpg
#   inflating: beagle_109.jpg
#   inflating: beagle_110.jpg
#   inflating: beagle_111.jpg
#   inflating: beagle_112.jpg
#   inflating: beagle_113.jpg
#   inflating: beagle_114.jpg
#   inflating: beagle_115.jpg
#   inflating: beagle_116.jpg
#   inflating: beagle_117.jpg
#   inflating: beagle_118.jpg
#   inflating: beagle_119.jpg
#   inflating: beagle_12.jpg
#   inflating: beagle_120.jpg
#   inflating: beagle_121.jpg
#   inflating: beagle_122.jpg
#   inflating: beagle_123.jpg
#   inflating: beagle_124.jpg
#   inflating: beagle_125.jpg
#   inflating: beagle_126.jpg
#   inflating: beagle_127.jpg
#   inflating: beagle_128.jpg
#   inflating: beagle_129.jpg
#   inflating: beagle_13.jpg
#   inflating: beagle_130.jpg
#   inflating: beagle_131.jpg
#   inflating: beagle_133.jpg
#   inflating: beagle_134.jpg
#   inflating: beagle_135.jpg
#   inflating: beagle_136.jpg
#   inflating: beagle_137.jpg
#   inflating: beagle_138.jpg
#   inflating: beagle_139.jpg
#   inflating: beagle_14.jpg
#   inflating: beagle_140.jpg
#   inflating: beagle_141.jpg
#   inflating: beagle_142.jpg
#   inflating: beagle_143.jpg
#   inflating: beagle_144.jpg
#   inflating: beagle_145.jpg
#   inflating: beagle_146.jpg
#   inflating: beagle_147.jpg
#   inflating: beagle_148.jpg
#   inflating: beagle_149.jpg
#   inflating: beagle_15.jpg
#   inflating: beagle_150.jpg
#   inflating: beagle_151.jpg
#   inflating: beagle_152.jpg
#   inflating: beagle_153.jpg
#   inflating: beagle_154.jpg
#   inflating: beagle_155.jpg
#   inflating: beagle_156.jpg
#   inflating: beagle_157.jpg
#   inflating: beagle_158.jpg
#   inflating: beagle_16.jpg
#   inflating: beagle_160.jpg
#   inflating: beagle_161.jpg
#   inflating: beagle_162.jpg
#   inflating: beagle_163.jpg
#   inflating: beagle_164.jpg
#   inflating: beagle_165.jpg
#   inflating: beagle_166.jpg
#   inflating: beagle_167.jpg
#   inflating: beagle_168.jpg
#   inflating: beagle_169.jpg
#   inflating: beagle_17.jpg
#   inflating: beagle_170.jpg
#   inflating: beagle_171.jpg
#   inflating: beagle_172.jpg
#   inflating: beagle_173.jpg
#   inflating: beagle_174.jpg
#   inflating: beagle_175.jpg
#   inflating: beagle_176.jpg
#   inflating: beagle_177.jpg
#   inflating: beagle_178.jpg
#   inflating: beagle_179.jpg
#   inflating: beagle_18.jpg
#   inflating: beagle_180.jpg
#   inflating: beagle_181.jpg
#   inflating: beagle_182.jpg
#   inflating: beagle_183.jpg
#   inflating: beagle_184.jpg
#   inflating: beagle_185.jpg
#   inflating: beagle_186.jpg
#   inflating: beagle_187.jpg
#   inflating: beagle_188.jpg
#   inflating: beagle_189.jpg
#   inflating: beagle_19.jpg
#   inflating: beagle_190.jpg
#   inflating: beagle_191.jpg
#   inflating: beagle_192.jpg
#   inflating: beagle_193.jpg
#   inflating: beagle_194.jpg
#   inflating: beagle_195.jpg
#   inflating: beagle_196.jpg
#   inflating: beagle_197.jpg
#   inflating: beagle_198.jpg
#   inflating: beagle_199.jpg
#   inflating: beagle_2.jpg
#   inflating: beagle_20.jpg
#   inflating: beagle_200.jpg
#   inflating: beagle_201.jpg
#   inflating: beagle_202.jpg
#   inflating: beagle_203.jpg
#   inflating: beagle_204.jpg
#   inflating: beagle_21.jpg
#   inflating: beagle_22.jpg
#   inflating: beagle_23.jpg
#   inflating: beagle_24.jpg
#   inflating: beagle_25.jpg
#   inflating: beagle_26.jpg
#   inflating: beagle_27.jpg
#   inflating: beagle_28.jpg
#   inflating: beagle_29.jpg
#   inflating: beagle_3.jpg
#   inflating: beagle_30.jpg
#   inflating: beagle_31.jpg
#   inflating: beagle_32.jpg
#   inflating: beagle_33.jpg
#   inflating: beagle_34.jpg
#   inflating: beagle_35.jpg
#   inflating: beagle_36.jpg
#   inflating: beagle_37.jpg
#   inflating: beagle_38.jpg
#   inflating: beagle_39.jpg
#   inflating: beagle_4.jpg
#   inflating: beagle_40.jpg
#   inflating: beagle_41.jpg
#   inflating: beagle_42.jpg
#   inflating: beagle_43.jpg
#   inflating: beagle_44.jpg
#   inflating: beagle_45.jpg
#   inflating: beagle_46.jpg
#   inflating: beagle_47.jpg
#   inflating: beagle_48.jpg
#   inflating: beagle_49.jpg
#   inflating: beagle_5.jpg
#   inflating: beagle_50.jpg
#   inflating: beagle_51.jpg
#   inflating: beagle_52.jpg
#   inflating: beagle_53.jpg
#   inflating: beagle_54.jpg
#   inflating: beagle_55.jpg
#   inflating: beagle_56.jpg
#   inflating: beagle_57.jpg
#   inflating: beagle_58.jpg
#   inflating: beagle_59.jpg
#   inflating: beagle_6.jpg
#   inflating: beagle_60.jpg
#   inflating: beagle_61.jpg
#   inflating: beagle_62.jpg
#   inflating: beagle_63.jpg
#   inflating: beagle_64.jpg
#   inflating: beagle_65.jpg
#   inflating: beagle_66.jpg
#   inflating: beagle_67.jpg
#   inflating: beagle_68.jpg
#   inflating: beagle_69.jpg
#   inflating: beagle_7.jpg
#   inflating: beagle_70.jpg
#   inflating: beagle_71.jpg
#   inflating: beagle_72.jpg
#   inflating: beagle_73.jpg
#   inflating: beagle_74.jpg
#   inflating: beagle_75.jpg
#   inflating: beagle_76.jpg
#   inflating: beagle_77.jpg
#   inflating: beagle_78.jpg
#   inflating: beagle_79.jpg
#   inflating: beagle_8.jpg
#   inflating: beagle_80.jpg
#   inflating: beagle_81.jpg
#   inflating: beagle_82.jpg
#   inflating: beagle_83.jpg
#   inflating: beagle_84.jpg
#   inflating: beagle_85.jpg
#   inflating: beagle_86.jpg
#   inflating: beagle_87.jpg
#   inflating: beagle_88.jpg
#   inflating: beagle_89.jpg
#   inflating: beagle_9.jpg
#   inflating: beagle_90.jpg
#   inflating: beagle_91.jpg
#   inflating: beagle_92.jpg
#   inflating: beagle_93.jpg
#   inflating: beagle_94.jpg
#   inflating: beagle_95.jpg
#   inflating: beagle_96.jpg
#   inflating: beagle_97.jpg
#   inflating: beagle_98.jpg
#   inflating: beagle_99.jpg
#   inflating: n02088364_10108.jpg
#   inflating: n02088364_10206.jpg
#   inflating: n02088364_10296.jpg
#   inflating: n02088364_10354.jpg
#   inflating: n02088364_10362.jpg
#   inflating: n02088364_10575.jpg
#   inflating: n02088364_10585.jpg
#   inflating: n02088364_10731.jpg
#   inflating: n02088364_10798.jpg
#   inflating: n02088364_10947.jpg
#   inflating: n02088364_11130.jpg
#   inflating: n02088364_11136.jpg
#   inflating: n02088364_11147.jpg
#   inflating: n02088364_11231.jpg
#   inflating: n02088364_1128.jpg
#   inflating: n02088364_11391.jpg
#   inflating: n02088364_11458.jpg
#   inflating: n02088364_11509.jpg
#   inflating: n02088364_11698.jpg
#   inflating: n02088364_11711.jpg
#   inflating: n02088364_11828.jpg
#   inflating: n02088364_11836.jpg
#   inflating: n02088364_11930.jpg
#   inflating: n02088364_12102.jpg
#   inflating: n02088364_12124.jpg
#   inflating: n02088364_12131.jpg
#   inflating: n02088364_12154.jpg
#   inflating: n02088364_12178.jpg
#   inflating: n02088364_12213.jpg
#   inflating: n02088364_12291.jpg
#   inflating: n02088364_12303.jpg
#   inflating: n02088364_12334.jpg
#   inflating: n02088364_12397.jpg
#   inflating: n02088364_12405.jpg
#   inflating: n02088364_12440.jpg
#   inflating: n02088364_12710.jpg
#   inflating: n02088364_12713.jpg
#   inflating: n02088364_12745.jpg
#   inflating: n02088364_12756.jpg
#   inflating: n02088364_12794.jpg
#   inflating: n02088364_12816.jpg
#   inflating: n02088364_12869.jpg
#   inflating: n02088364_129.jpg
#   inflating: n02088364_12920.jpg
#   inflating: n02088364_12972.jpg
#   inflating: n02088364_12973.jpg
#   inflating: n02088364_13028.jpg
#   inflating: n02088364_13050.jpg
#   inflating: n02088364_13128.jpg
#   inflating: n02088364_13214.jpg
#   inflating: n02088364_13236.jpg
#   inflating: n02088364_13428.jpg
#   inflating: n02088364_13464.jpg
#   inflating: n02088364_13477.jpg
#   inflating: n02088364_13478.jpg
#   inflating: n02088364_13484.jpg
#   inflating: n02088364_13572.jpg
#   inflating: n02088364_13627.jpg
#   inflating: n02088364_13630.jpg
#   inflating: n02088364_13682.jpg
#   inflating: n02088364_13809.jpg
#   inflating: n02088364_1384.jpg
#   inflating: n02088364_13944.jpg
#   inflating: n02088364_13981.jpg
#   inflating: n02088364_14055.jpg
#   inflating: n02088364_14079.jpg
#   inflating: n02088364_14095.jpg
#   inflating: n02088364_14220.jpg
#   inflating: n02088364_14369.jpg
#   inflating: n02088364_14394.jpg
#   inflating: n02088364_14431.jpg
#   inflating: n02088364_14548.jpg
#   inflating: n02088364_14613.jpg
#   inflating: n02088364_14663.jpg
#   inflating: n02088364_14690.jpg
#   inflating: n02088364_14702.jpg
#   inflating: n02088364_14779.jpg
#   inflating: n02088364_14863.jpg
#   inflating: n02088364_14892.jpg
#   inflating: n02088364_14911.jpg
#   inflating: n02088364_14968.jpg
#   inflating: n02088364_15036.jpg
#   inflating: n02088364_1507.jpg
#   inflating: n02088364_15082.jpg
#   inflating: n02088364_15093.jpg
#   inflating: n02088364_15111.jpg
#   inflating: n02088364_15305.jpg
#   inflating: n02088364_15315.jpg
#   inflating: n02088364_15370.jpg
#   inflating: n02088364_15690.jpg
#   inflating: n02088364_15787.jpg
#   inflating: n02088364_15877.jpg
#   inflating: n02088364_16060.jpg
#   inflating: n02088364_16065.jpg
#   inflating: n02088364_161.jpg
#   inflating: n02088364_16165.jpg
#   inflating: n02088364_16207.jpg
#   inflating: n02088364_16210.jpg
#   inflating: n02088364_16339.jpg
#   inflating: n02088364_16493.jpg
#   inflating: n02088364_16502.jpg
#   inflating: n02088364_16508.jpg
#   inflating: n02088364_16519.jpg
#   inflating: n02088364_16588.jpg
#   inflating: n02088364_16635.jpg
#   inflating: n02088364_16689.jpg
#   inflating: n02088364_16695.jpg
#   inflating: n02088364_16704.jpg
#   inflating: n02088364_16721.jpg
#   inflating: n02088364_16791.jpg
#   inflating: n02088364_16881.jpg
#   inflating: n02088364_16985.jpg
#   inflating: n02088364_17167.jpg
#   inflating: n02088364_17170.jpg
#   inflating: n02088364_17258.jpg
#   inflating: n02088364_17294.jpg
#   inflating: n02088364_17314.jpg
#   inflating: n02088364_17406.jpg
#   inflating: n02088364_17473.jpg
#   inflating: n02088364_17474.jpg
#   inflating: n02088364_17479.jpg
#   inflating: n02088364_17530.jpg
#   inflating: n02088364_17534.jpg
#   inflating: n02088364_17553.jpg
#   inflating: n02088364_17671.jpg
#   inflating: n02088364_17689.jpg
#   inflating: n02088364_17766.jpg
#   inflating: n02088364_17935.jpg
#   inflating: n02088364_18403.jpg
#   inflating: n02088364_2000.jpg
#   inflating: n02088364_2019.jpg
#   inflating: n02088364_2106.jpg
#   inflating: n02088364_2143.jpg
#   inflating: n02088364_2360.jpg
#   inflating: n02088364_2415.jpg
#   inflating: n02088364_2499.jpg
#   inflating: n02088364_2502.jpg
#   inflating: n02088364_2566.jpg
#   inflating: n02088364_2572.jpg
#   inflating: n02088364_2652.jpg
#   inflating: n02088364_2661.jpg
#   inflating: n02088364_2840.jpg
#   inflating: n02088364_3171.jpg
#   inflating: n02088364_3752.jpg
#   inflating: n02088364_3758.jpg
#   inflating: n02088364_4052.jpg
#   inflating: n02088364_4070.jpg
#   inflating: n02088364_4237.jpg
#   inflating: n02088364_427.jpg
#   inflating: n02088364_4281.jpg
#   inflating: n02088364_4473.jpg
#   inflating: n02088364_4493.jpg
#   inflating: n02088364_4527.jpg
#   inflating: n02088364_4706.jpg
#   inflating: n02088364_4823.jpg
#   inflating: n02088364_4879.jpg
#   inflating: n02088364_5090.jpg
#   inflating: n02088364_5123.jpg
#   inflating: n02088364_5147.jpg
#   inflating: n02088364_5282.jpg
#   inflating: n02088364_5427.jpg
#   inflating: n02088364_5572.jpg
#   inflating: n02088364_5716.jpg
#   inflating: n02088364_5784.jpg
#   inflating: n02088364_5826.jpg
#   inflating: n02088364_6089.jpg
#   inflating: n02088364_6109.jpg
#   inflating: n02088364_6211.jpg
#   inflating: n02088364_6358.jpg
#   inflating: n02088364_639.jpg
#   inflating: n02088364_6547.jpg
#   inflating: n02088364_6611.jpg
#   inflating: n02088364_6866.jpg
#   inflating: n02088364_7247.jpg
#   inflating: n02088364_7324.jpg
#   inflating: n02088364_769.jpg
#   inflating: n02088364_7784.jpg
#   inflating: n02088364_7927.jpg
#   inflating: n02088364_8443.jpg
#   inflating: n02088364_8477.jpg
#   inflating: n02088364_852.jpg
#   inflating: n02088364_8572.jpg
#   inflating: n02088364_8612.jpg
#   inflating: n02088364_8713.jpg
#   inflating: n02088364_876.jpg
#   inflating: n02088364_8820.jpg
#   inflating: n02088364_8871.jpg
#   inflating: n02088364_9318.jpg
#   inflating: n02088364_9520.jpg
#   inflating: n02088364_959.jpg
#   inflating: n02088364_9650.jpg
#   inflating: n02088364_9652.jpg
#   inflating: n02088364_9825.jpg
#   inflating: n02088364_9849.jpg
#   inflating: n02088364_9895.jpg
# /content
# /content/pug
# Archive:  PUG.zip
#   inflating: n02110958_10.jpg
#   inflating: n02110958_10186.jpg
#   inflating: n02110958_10193.jpg
#   inflating: n02110958_10378.jpg
#   inflating: n02110958_10842.jpg
#   inflating: n02110958_1108.jpg
#   inflating: n02110958_11083.jpg
#   inflating: n02110958_11194.jpg
#   inflating: n02110958_11209.jpg
#   inflating: n02110958_11239.jpg
#   inflating: n02110958_11256.jpg
#   inflating: n02110958_11261.jpg
#   inflating: n02110958_11288.jpg
#   inflating: n02110958_11306.jpg
#   inflating: n02110958_11359.jpg
#   inflating: n02110958_11458.jpg
#   inflating: n02110958_11632.jpg
#   inflating: n02110958_11675.jpg
#   inflating: n02110958_11725.jpg
#   inflating: n02110958_11732.jpg
#   inflating: n02110958_11825.jpg
#   inflating: n02110958_11870.jpg
#   inflating: n02110958_11958.jpg
#   inflating: n02110958_11977.jpg
#   inflating: n02110958_11979.jpg
#   inflating: n02110958_12025.jpg
#   inflating: n02110958_12080.jpg
#   inflating: n02110958_12120.jpg
#   inflating: n02110958_12128.jpg
#   inflating: n02110958_12130.jpg
#   inflating: n02110958_12149.jpg
#   inflating: n02110958_12224.jpg
#   inflating: n02110958_12260.jpg
#   inflating: n02110958_12275.jpg
#   inflating: n02110958_12350.jpg
#   inflating: n02110958_12432.jpg
#   inflating: n02110958_12447.jpg
#   inflating: n02110958_12589.jpg
#   inflating: n02110958_12611.jpg
#   inflating: n02110958_12625.jpg
#   inflating: n02110958_12761.jpg
#   inflating: n02110958_12781.jpg
#   inflating: n02110958_12807.jpg
#   inflating: n02110958_12808.jpg
#   inflating: n02110958_12819.jpg
#   inflating: n02110958_12860.jpg
#   inflating: n02110958_12934.jpg
#   inflating: n02110958_13002.jpg
#   inflating: n02110958_13023.jpg
#   inflating: n02110958_13042.jpg
#   inflating: n02110958_13051.jpg
#   inflating: n02110958_13224.jpg
#   inflating: n02110958_13256.jpg
#   inflating: n02110958_13263.jpg
#   inflating: n02110958_13276.jpg
#   inflating: n02110958_13340.jpg
#   inflating: n02110958_13342.jpg
#   inflating: n02110958_13364.jpg
#   inflating: n02110958_13391.jpg
#   inflating: n02110958_13439.jpg
#   inflating: n02110958_13455.jpg
#   inflating: n02110958_13469.jpg
#   inflating: n02110958_13506.jpg
#   inflating: n02110958_13560.jpg
#   inflating: n02110958_13581.jpg
#   inflating: n02110958_13597.jpg
#   inflating: n02110958_13721.jpg
#   inflating: n02110958_13794.jpg
#   inflating: n02110958_13812.jpg
#   inflating: n02110958_13930.jpg
#   inflating: n02110958_13993.jpg
#   inflating: n02110958_13995.jpg
#   inflating: n02110958_14017.jpg
#   inflating: n02110958_14111.jpg
#   inflating: n02110958_14142.jpg
#   inflating: n02110958_14154.jpg
#   inflating: n02110958_14179.jpg
#   inflating: n02110958_14265.jpg
#   inflating: n02110958_14311.jpg
#   inflating: n02110958_14449.jpg
#   inflating: n02110958_14536.jpg
#   inflating: n02110958_14549.jpg
#   inflating: n02110958_14563.jpg
#   inflating: n02110958_14594.jpg
#   inflating: n02110958_14647.jpg
#   inflating: n02110958_14654.jpg
#   inflating: n02110958_14683.jpg
#   inflating: n02110958_14711.jpg
#   inflating: n02110958_14768.jpg
#   inflating: n02110958_14832.jpg
#   inflating: n02110958_14927.jpg
#   inflating: n02110958_14984.jpg
#   inflating: n02110958_14996.jpg
#   inflating: n02110958_15014.jpg
#   inflating: n02110958_15015.jpg
#   inflating: n02110958_15120.jpg
#   inflating: n02110958_15129.jpg
#   inflating: n02110958_15130.jpg
#   inflating: n02110958_15171.jpg
#   inflating: n02110958_152.jpg
#   inflating: n02110958_15216.jpg
#   inflating: n02110958_15217.jpg
#   inflating: n02110958_15351.jpg
#   inflating: n02110958_15352.jpg
#   inflating: n02110958_15364.jpg
#   inflating: n02110958_15422.jpg
#   inflating: n02110958_15449.jpg
#   inflating: n02110958_15527.jpg
#   inflating: n02110958_15538.jpg
#   inflating: n02110958_15550.jpg
#   inflating: n02110958_15615.jpg
#   inflating: n02110958_15626.jpg
#   inflating: n02110958_15663.jpg
#   inflating: n02110958_15722.jpg
#   inflating: n02110958_15734.jpg
#   inflating: n02110958_15746.jpg
#   inflating: n02110958_15766.jpg
#   inflating: n02110958_15873.jpg
#   inflating: n02110958_15877.jpg
#   inflating: n02110958_15932.jpg
#   inflating: n02110958_15969.jpg
#   inflating: n02110958_15981.jpg
#   inflating: n02110958_16082.jpg
#   inflating: n02110958_16087.jpg
#   inflating: n02110958_16132.jpg
#   inflating: n02110958_16150.jpg
#   inflating: n02110958_16178.jpg
#   inflating: n02110958_16217.jpg
#   inflating: n02110958_16330.jpg
#   inflating: n02110958_16334.jpg
#   inflating: n02110958_16337.jpg
#   inflating: n02110958_1636.jpg
#   inflating: n02110958_1639.jpg
#   inflating: n02110958_16426.jpg
#   inflating: n02110958_16433.jpg
#   inflating: n02110958_16434.jpg
#   inflating: n02110958_16447.jpg
#   inflating: n02110958_16453.jpg
#   inflating: n02110958_16471.jpg
#   inflating: n02110958_16492.jpg
#   inflating: n02110958_1975.jpg
#   inflating: n02110958_2009.jpg
#   inflating: n02110958_2041.jpg
#   inflating: n02110958_2144.jpg
#   inflating: n02110958_2154.jpg
#   inflating: n02110958_237.jpg
#   inflating: n02110958_2410.jpg
#   inflating: n02110958_25.jpg
#   inflating: n02110958_2611.jpg
#   inflating: n02110958_2745.jpg
#   inflating: n02110958_2777.jpg
#   inflating: n02110958_326.jpg
#   inflating: n02110958_3338.jpg
#   inflating: n02110958_340.jpg
#   inflating: n02110958_353.jpg
#   inflating: n02110958_3644.jpg
#   inflating: n02110958_3795.jpg
#   inflating: n02110958_3938.jpg
#   inflating: n02110958_4030.jpg
#   inflating: n02110958_4036.jpg
#   inflating: n02110958_4043.jpg
#   inflating: n02110958_4189.jpg
#   inflating: n02110958_476.jpg
#   inflating: n02110958_481.jpg
#   inflating: n02110958_483.jpg
#   inflating: n02110958_4993.jpg
#   inflating: n02110958_5069.jpg
#   inflating: n02110958_5555.jpg
#   inflating: n02110958_5621.jpg
#   inflating: n02110958_5788.jpg
#   inflating: n02110958_5834.jpg
#   inflating: n02110958_589.jpg
#   inflating: n02110958_5912.jpg
#   inflating: n02110958_5976.jpg
#   inflating: n02110958_609.jpg
#   inflating: n02110958_6098.jpg
#   inflating: n02110958_6274.jpg
#   inflating: n02110958_630.jpg
#   inflating: n02110958_6598.jpg
#   inflating: n02110958_6627.jpg
#   inflating: n02110958_6792.jpg
#   inflating: n02110958_6966.jpg
#   inflating: n02110958_7027.jpg
#   inflating: n02110958_7255.jpg
#   inflating: n02110958_7698.jpg
#   inflating: n02110958_771.jpg
#   inflating: n02110958_7801.jpg
#   inflating: n02110958_7915.jpg
#   inflating: n02110958_8075.jpg
#   inflating: n02110958_8513.jpg
#   inflating: n02110958_8583.jpg
#   inflating: n02110958_8627.jpg
#   inflating: n02110958_8724.jpg
#   inflating: n02110958_8814.jpg
#   inflating: n02110958_8887.jpg
#   inflating: n02110958_8979.jpg
#   inflating: n02110958_9008.jpg
#   inflating: n02110958_9505.jpg
#   inflating: n02110958_9642.jpg
#   inflating: n02110958_9929.jpg
#   inflating: pug_1.jpg
#   inflating: pug_10.jpg
#   inflating: pug_100.jpg
#   inflating: pug_101.jpg
#   inflating: pug_102.jpg
#   inflating: pug_103.jpg
#   inflating: pug_104.jpg
#   inflating: pug_105.jpg
#   inflating: pug_106.jpg
#   inflating: pug_107.jpg
#   inflating: pug_108.jpg
#   inflating: pug_109.jpg
#   inflating: pug_11.jpg
#   inflating: pug_110.jpg
#   inflating: pug_111.jpg
#   inflating: pug_112.jpg
#   inflating: pug_114.jpg
#   inflating: pug_115.jpg
#   inflating: pug_116.jpg
#   inflating: pug_117.jpg
#   inflating: pug_118.jpg
#   inflating: pug_119.jpg
#   inflating: pug_12.jpg
#   inflating: pug_120.jpg
#   inflating: pug_121.jpg
#   inflating: pug_122.jpg
#   inflating: pug_123.jpg
#   inflating: pug_124.jpg
#   inflating: pug_125.jpg
#   inflating: pug_126.jpg
#   inflating: pug_127.jpg
#   inflating: pug_128.jpg
#   inflating: pug_129.jpg
#   inflating: pug_13.jpg
#   inflating: pug_130.jpg
#   inflating: pug_131.jpg
#   inflating: pug_132.jpg
#   inflating: pug_133.jpg
#   inflating: pug_134.jpg
#   inflating: pug_135.jpg
#   inflating: pug_136.jpg
#   inflating: pug_137.jpg
#   inflating: pug_138.jpg
#   inflating: pug_139.jpg
#   inflating: pug_14.jpg
#   inflating: pug_140.jpg
#   inflating: pug_141.jpg
#   inflating: pug_142.jpg
#   inflating: pug_143.jpg
#   inflating: pug_144.jpg
#   inflating: pug_145.jpg
#   inflating: pug_146.jpg
#   inflating: pug_147.jpg
#   inflating: pug_148.jpg
#   inflating: pug_149.jpg
#   inflating: pug_15.jpg
#   inflating: pug_150.jpg
#   inflating: pug_151.jpg
#   inflating: pug_153.jpg
#   inflating: pug_154.jpg
#   inflating: pug_155.jpg
#   inflating: pug_156.jpg
#   inflating: pug_157.jpg
#   inflating: pug_158.jpg
#   inflating: pug_159.jpg
#   inflating: pug_16.jpg
#   inflating: pug_160.jpg
#   inflating: pug_161.jpg
#   inflating: pug_162.jpg
#   inflating: pug_163.jpg
#   inflating: pug_164.jpg
#   inflating: pug_165.jpg
#   inflating: pug_166.jpg
#   inflating: pug_167.jpg
#   inflating: pug_168.jpg
#   inflating: pug_169.jpg
#   inflating: pug_17.jpg
#   inflating: pug_170.jpg
#   inflating: pug_171.jpg
#   inflating: pug_172.jpg
#   inflating: pug_173.jpg
#   inflating: pug_174.jpg
#   inflating: pug_175.jpg
#   inflating: pug_176.jpg
#   inflating: pug_177.jpg
#   inflating: pug_178.jpg
#   inflating: pug_179.jpg
#   inflating: pug_18.jpg
#   inflating: pug_180.jpg
#   inflating: pug_181.jpg
#   inflating: pug_182.jpg
#   inflating: pug_183.jpg
#   inflating: pug_184.jpg
#   inflating: pug_185.jpg
#   inflating: pug_186.jpg
#   inflating: pug_187.jpg
#   inflating: pug_188.jpg
#   inflating: pug_189.jpg
#   inflating: pug_19.jpg
#   inflating: pug_190.jpg
#   inflating: pug_191.jpg
#   inflating: pug_192.jpg
#   inflating: pug_193.jpg
#   inflating: pug_194.jpg
#   inflating: pug_195.jpg
#   inflating: pug_196.jpg
#   inflating: pug_197.jpg
#   inflating: pug_198.jpg
#   inflating: pug_199.jpg
#   inflating: pug_2.jpg
#   inflating: pug_20.jpg
#   inflating: pug_200.jpg
#   inflating: pug_201.jpg
#   inflating: pug_202.jpg
#   inflating: pug_203.jpg
#   inflating: pug_21.jpg
#   inflating: pug_22.jpg
#   inflating: pug_23.jpg
#   inflating: pug_24.jpg
#   inflating: pug_25.jpg
#   inflating: pug_26.jpg
#   inflating: pug_27.jpg
#   inflating: pug_28.jpg
#   inflating: pug_29.jpg
#   inflating: pug_3.jpg
#   inflating: pug_30.jpg
#   inflating: pug_31.jpg
#   inflating: pug_32.jpg
#   inflating: pug_33.jpg
#   inflating: pug_34.jpg
#   inflating: pug_35.jpg
#   inflating: pug_36.jpg
#   inflating: pug_37.jpg
#   inflating: pug_38.jpg
#   inflating: pug_39.jpg
#   inflating: pug_4.jpg
#   inflating: pug_40.jpg
#   inflating: pug_41.jpg
#   inflating: pug_42.jpg
#   inflating: pug_43.jpg
#   inflating: pug_44.jpg
#   inflating: pug_45.jpg
#   inflating: pug_46.jpg
#   inflating: pug_47.jpg
#   inflating: pug_48.jpg
#   inflating: pug_49.jpg
#   inflating: pug_5.jpg
#   inflating: pug_50.jpg
#   inflating: pug_51.jpg
#   inflating: pug_52.jpg
#   inflating: pug_53.jpg
#   inflating: pug_54.jpg
#   inflating: pug_55.jpg
#   inflating: pug_56.jpg
#   inflating: pug_57.jpg
#   inflating: pug_58.jpg
#   inflating: pug_59.jpg
#   inflating: pug_6.jpg
#   inflating: pug_60.jpg
#   inflating: pug_61.jpg
#   inflating: pug_62.jpg
#   inflating: pug_63.jpg
#   inflating: pug_64.jpg
#   inflating: pug_65.jpg
#   inflating: pug_66.jpg
#   inflating: pug_67.jpg
#   inflating: pug_68.jpg
#   inflating: pug_69.jpg
#   inflating: pug_7.jpg
#   inflating: pug_70.jpg
#   inflating: pug_71.jpg
#   inflating: pug_72.jpg
#   inflating: pug_73.jpg
#   inflating: pug_74.jpg
#   inflating: pug_75.jpg
#   inflating: pug_76.jpg
#   inflating: pug_77.jpg
#   inflating: pug_78.jpg
#   inflating: pug_79.jpg
#   inflating: pug_8.jpg
#   inflating: pug_80.jpg
#   inflating: pug_81.jpg
#   inflating: pug_82.jpg
#   inflating: pug_84.jpg
#   inflating: pug_85.jpg
#   inflating: pug_86.jpg
#   inflating: pug_87.jpg
#   inflating: pug_88.jpg
#   inflating: pug_89.jpg
#   inflating: pug_9.jpg
#   inflating: pug_90.jpg
#   inflating: pug_91.jpg
#   inflating: pug_92.jpg
#   inflating: pug_93.jpg
#   inflating: pug_94.jpg
#   inflating: pug_95.jpg
#   inflating: pug_96.jpg
#   inflating: pug_97.jpg
#   inflating: pug_98.jpg
#   inflating: pug_99.jpg
# /content
# /content/otros
# Archive:  OTROS.zip
#   inflating: OTROS/boxer_57.jpg
#   inflating: OTROS/boxer_58.jpg
#   inflating: OTROS/boxer_59.jpg
#   inflating: OTROS/boxer_6.jpg
#   inflating: OTROS/boxer_60.jpg
#   inflating: OTROS/boxer_61.jpg
#   inflating: OTROS/boxer_62.jpg
#   inflating: OTROS/boxer_63.jpg
#   inflating: OTROS/boxer_64.jpg
#   inflating: OTROS/boxer_65.jpg
#   inflating: OTROS/boxer_66.jpg
#   inflating: OTROS/boxer_67.jpg
#   inflating: OTROS/boxer_68.jpg
#   inflating: OTROS/boxer_69.jpg
#   inflating: OTROS/boxer_7.jpg
#   inflating: OTROS/boxer_70.jpg
#   inflating: OTROS/boxer_75.jpg
#   inflating: OTROS/boxer_76.jpg
#   inflating: OTROS/boxer_77.jpg
#   inflating: OTROS/boxer_78.jpg
#   inflating: OTROS/boxer_79.jpg
#   inflating: OTROS/boxer_80.jpg
#   inflating: OTROS/boxer_81.jpg
#   inflating: OTROS/boxer_82.jpg
#   inflating: OTROS/boxer_83.jpg
#   inflating: OTROS/boxer_84.jpg
#   inflating: OTROS/boxer_85.jpg
#   inflating: OTROS/collie35.jpg
#   inflating: OTROS/collie36.jpg
#   inflating: OTROS/collie37.jpg
#   inflating: OTROS/collie38.jpg
#   inflating: OTROS/collie39.jpg
#   inflating: OTROS/collie4.jpg
#   inflating: OTROS/collie40.jpg
#   inflating: OTROS/collie41.jpg
#   inflating: OTROS/collie42.jpg
#   inflating: OTROS/collie43.jpg
#   inflating: OTROS/collie44.jpg
#   inflating: OTROS/collie45.jpg
#   inflating: OTROS/collie46.jpg
#   inflating: OTROS/collie47.jpg
#   inflating: OTROS/collie48.jpg
#   inflating: OTROS/collie5.jpg
#   inflating: OTROS/collie64.jpg
#   inflating: OTROS/collie65.jpg
#   inflating: OTROS/collie66.jpg
#   inflating: OTROS/collie67.jpg
#   inflating: OTROS/collie68.jpg
#   inflating: OTROS/collie69.jpg
#   inflating: OTROS/collie70.jpg
#   inflating: OTROS/collie71.jpg
#   inflating: OTROS/collie72.jpg
#   inflating: OTROS/collie73.jpg
#   inflating: OTROS/collie74.jpg
#   inflating: OTROS/collie75.jpg
#   inflating: OTROS/collie76.jpg
#   inflating: OTROS/collie78.jpg
#   inflating: OTROS/collie80.jpg
#   inflating: OTROS/collie81.jpg
#   inflating: OTROS/collie82.jpg
#   inflating: OTROS/gr20.jpg
#   inflating: OTROS/gr21.jpg
#   inflating: OTROS/gr22.jpg
#   inflating: OTROS/gr23.jpg
#   inflating: OTROS/gr25.jpg
#   inflating: OTROS/gr26.jpg
#   inflating: OTROS/gr29.jpg
#   inflating: OTROS/gr3.jpg
#   inflating: OTROS/gr30.jpg
#   inflating: OTROS/gr32.jpg
#   inflating: OTROS/gr34.jpg
#   inflating: OTROS/gr37.jpg
#   inflating: OTROS/gr39.jpg
#   inflating: OTROS/gr40.jpg
#   inflating: OTROS/gr41.jpg
#   inflating: OTROS/gr42.jpg
#   inflating: OTROS/gr43.jpg
#   inflating: OTROS/gr44.jpg
#   inflating: OTROS/gr46.jpg
#   inflating: OTROS/gr47.jpg
#   inflating: OTROS/gr48.jpg
#   inflating: OTROS/gr49.jpg
#   inflating: OTROS/gr5.jpg
#   inflating: OTROS/gr50.jpg
#   inflating: OTROS/gr53.jpg
#   inflating: OTROS/gr54.jpg
#   inflating: OTROS/gr55.jpg
#   inflating: OTROS/gr56.jpg
#   inflating: OTROS/gr57.jpg
#   inflating: OTROS/gr58.jpg
#   inflating: OTROS/gr59.jpg
#   inflating: OTROS/gr60.jpg
#   inflating: OTROS/gr61.jpg
#   inflating: OTROS/gr62.jpg
#   inflating: OTROS/gr63.jpg
#   inflating: OTROS/gr77.jpg
#   inflating: OTROS/gr78.jpg
#   inflating: OTROS/gr79.jpg
#   inflating: OTROS/gr8.jpg
#   inflating: OTROS/gr80.jpg
#   inflating: OTROS/gr82.jpg
#   inflating: OTROS/gr84.jpg
#   inflating: OTROS/gr85.jpg
#   inflating: OTROS/gr86.jpg
#   inflating: OTROS/gr9.jpg
#   inflating: OTROS/gr91.jpg
#   inflating: OTROS/gr92.jpg
#   inflating: OTROS/gr93.jpg
#   inflating: OTROS/gr94.jpg
#   inflating: OTROS/gr95.jpg
#   inflating: OTROS/gr96.jpg
#   inflating: OTROS/gr98.jpg
#   inflating: OTROS/gr99.jpg
#   inflating: OTROS/husky34.jpg
#   inflating: OTROS/husky35.jpg
#   inflating: OTROS/husky36.jpg
#   inflating: OTROS/husky37.jpg
#   inflating: OTROS/husky38.jpg
#   inflating: OTROS/husky39.jpg
#   inflating: OTROS/husky4.jpg
#   inflating: OTROS/husky40.jpg
#   inflating: OTROS/husky41.jpg
#   inflating: OTROS/husky42.jpg
#   inflating: OTROS/husky45.jpg
#   inflating: OTROS/husky48.jpg
#   inflating: OTROS/husky49.jpg
#   inflating: OTROS/husky5.jpg
#   inflating: OTROS/husky50.jpg
#   inflating: OTROS/husky51.jpg
#   inflating: OTROS/husky52.jpg
#   inflating: OTROS/husky53.jpg
#   inflating: OTROS/husky54.jpg
#   inflating: OTROS/husky55.jpg
#   inflating: OTROS/husky56.jpg
#   inflating: OTROS/husky57.jpg
#   inflating: OTROS/husky58.jpg
#   inflating: OTROS/husky59.jpg
#   inflating: OTROS/husky6.jpg
#   inflating: OTROS/husky60.jpg
#   inflating: OTROS/husky61.jpg
#   inflating: OTROS/husky62.jpg
#   inflating: OTROS/husky63.jpg
#   inflating: OTROS/husky64.jpg
#   inflating: OTROS/husky66.jpg
#   inflating: OTROS/husky67.jpg
#   inflating: OTROS/husky68.jpg
#   inflating: OTROS/husky69.jpg
#   inflating: OTROS/husky7.jpg
#   inflating: OTROS/husky70.jpg
#   inflating: OTROS/husky71.jpg
#   inflating: OTROS/husky72.jpg
#   inflating: OTROS/husky73.jpg
#   inflating: OTROS/husky74.jpg
#   inflating: OTROS/husky75.jpg
#   inflating: OTROS/husky76.jpg
#   inflating: OTROS/husky77.jpg
#   inflating: OTROS/husky78.jpg
#   inflating: OTROS/husky79.jpg
#   inflating: OTROS/husky8.jpg
#   inflating: OTROS/husky80.jpg
#   inflating: OTROS/husky81.jpg
#   inflating: OTROS/husky82.jpg
#   inflating: OTROS/husky83.jpg
#   inflating: OTROS/husky85.jpg
#   inflating: OTROS/husky86.jpg
#   inflating: OTROS/husky87.jpg
#   inflating: OTROS/husky88.jpg
#   inflating: OTROS/husky89.jpg
#   inflating: OTROS/husky90.jpg
#   inflating: OTROS/husky91.jpg
#   inflating: OTROS/husky92.jpg
#   inflating: OTROS/husky93.jpg
#   inflating: OTROS/husky94.jpg
#   inflating: OTROS/husky95.jpg
#   inflating: OTROS/husky96.jpg
#   inflating: OTROS/jr22.jpg
#   inflating: OTROS/jr23.jpg
#   inflating: OTROS/jr24.jpg
#   inflating: OTROS/jr25.jpg
#   inflating: OTROS/jr26.jpg
#   inflating: OTROS/jr27.jpg
#   inflating: OTROS/jr3.jpg
#   inflating: OTROS/jr35.jpg
#   inflating: OTROS/jr36.jpg
#   inflating: OTROS/jr37.jpg
#   inflating: OTROS/jr39.jpg
#   inflating: OTROS/jr4.jpg
#   inflating: OTROS/jr40.jpg
#   inflating: OTROS/jr41.jpg
#   inflating: OTROS/jr42.jpg
#   inflating: OTROS/jr45.jpg
#   inflating: OTROS/jr46.jpg
#   inflating: OTROS/jr48.jpg
#   inflating: OTROS/jr5.jpg
#   inflating: OTROS/jr50.jpg
#   inflating: OTROS/jr51.jpg
#   inflating: OTROS/jr52.jpg
#   inflating: OTROS/jr53.jpg
#   inflating: OTROS/jr54.jpg
#   inflating: OTROS/jr55.jpg
#   inflating: OTROS/jr56.jpg
#   inflating: OTROS/jr57.jpg
#   inflating: OTROS/jr58.jpg
#   inflating: OTROS/jr59.jpg
#   inflating: OTROS/jr6.jpg
#   inflating: OTROS/jr60.jpg
#   inflating: OTROS/jr61.jpg
#   inflating: OTROS/jr62.jpg
#   inflating: OTROS/jr63.jpg
#   inflating: OTROS/jr68.jpg
#   inflating: OTROS/jr69.jpg
#   inflating: OTROS/jr70.jpg
#   inflating: OTROS/jr71.jpg
#   inflating: OTROS/jr72.jpg
#   inflating: OTROS/jr73.jpg
#   inflating: OTROS/jr74.jpg
#   inflating: OTROS/labrador100.jpg
#   inflating: OTROS/labrador12.jpg
#   inflating: OTROS/labrador13.jpg
#   inflating: OTROS/labrador15.jpg
#   inflating: OTROS/labrador16.jpg
#   inflating: OTROS/labrador17.jpg
#   inflating: OTROS/labrador18.jpg
#   inflating: OTROS/labrador19.jpg
#   inflating: OTROS/labrador2.jpg
#   inflating: OTROS/labrador21.jpg
#   inflating: OTROS/labrador22.jpg
#   inflating: OTROS/labrador23.jpg
#   inflating: OTROS/labrador24.jpg
#   inflating: OTROS/labrador26.jpg
#   inflating: OTROS/labrador27.jpg
#   inflating: OTROS/labrador28.jpg
#   inflating: OTROS/labrador29.jpg
#   inflating: OTROS/labrador3.jpg
#   inflating: OTROS/labrador30.jpg
#   inflating: OTROS/labrador31.jpg
#   inflating: OTROS/labrador32.jpg
#   inflating: OTROS/labrador33.jpg
#   inflating: OTROS/labrador34.jpg
#   inflating: OTROS/labrador35.jpg
#   inflating: OTROS/labrador36.jpg
#   inflating: OTROS/labrador37.jpg
#   inflating: OTROS/labrador38.jpg
#   inflating: OTROS/labrador39.jpg
#   inflating: OTROS/labrador4.jpg
#   inflating: OTROS/labrador40.jpg
#   inflating: OTROS/labrador41.jpg
#   inflating: OTROS/labrador42.jpg
#   inflating: OTROS/labrador43.jpg
#   inflating: OTROS/labrador44.jpg
#   inflating: OTROS/labrador45.jpg
#   inflating: OTROS/labrador46.jpg
#   inflating: OTROS/labrador59.jpg
#   inflating: OTROS/n02085620_4290.jpg
#   inflating: OTROS/n02085620_431.jpg
#   inflating: OTROS/n02085620_4441.jpg
#   inflating: OTROS/n02085620_4515.jpg
#   inflating: OTROS/n02085620_4572.jpg
#   inflating: OTROS/n02085620_4602.jpg
#   inflating: OTROS/n02085620_4673.jpg
#   inflating: OTROS/n02085620_4700.jpg
#   inflating: OTROS/n02085620_473.jpg
#   inflating: OTROS/n02085620_477.jpg
#   inflating: OTROS/n02085620_4814.jpg
#   inflating: OTROS/n02085620_4875.jpg
#   inflating: OTROS/n02085620_4919.jpg
#   inflating: OTROS/n02085620_4951.jpg
#   inflating: OTROS/n02085620_4980.jpg
#   inflating: OTROS/n02085620_500.jpg
#   inflating: OTROS/n02085620_574.jpg
#   inflating: OTROS/n02085620_575.jpg
#   inflating: OTROS/n02085620_5771.jpg
#   inflating: OTROS/n02085620_588.jpg
#   inflating: OTROS/n02085620_5927.jpg
#   inflating: OTROS/n02085620_6295.jpg
#   inflating: OTROS/n02085620_6399.jpg
#   inflating: OTROS/n02085620_6931.jpg
#   inflating: OTROS/n02085620_7.jpg
#   inflating: OTROS/n02085620_712.jpg
#   inflating: OTROS/n02085620_7292.jpg
#   inflating: OTROS/n02085620_730.jpg
#   inflating: OTROS/n02085620_735.jpg
#   inflating: OTROS/n02085620_7436.jpg
#   inflating: OTROS/n02085620_7440.jpg
#   inflating: OTROS/n02085620_7613.jpg
#   inflating: OTROS/n02085620_7700.jpg
#   inflating: OTROS/n02085620_7738.jpg
#   inflating: OTROS/n02085620_806.jpg
#   inflating: OTROS/n02085620_8420.jpg
#   inflating: OTROS/n02085620_8491.jpg
#   inflating: OTROS/n02085620_8558.jpg
#   inflating: OTROS/n02085620_8578.jpg
#   inflating: OTROS/n02085620_8585.jpg
#   inflating: OTROS/n02085620_8611.jpg
#   inflating: OTROS/n02085620_8636.jpg
#   inflating: OTROS/n02085620_8637.jpg
#   inflating: OTROS/n02085620_9351.jpg
#   inflating: OTROS/n02085620_9357.jpg
#   inflating: OTROS/n02085620_9399.jpg
#   inflating: OTROS/n02085620_9414.jpg
#   inflating: OTROS/n02085620_949.jpg
#   inflating: OTROS/n02085620_952.jpg
#   inflating: OTROS/n02085620_9654.jpg
#   inflating: OTROS/n02086240_7349.jpg
#   inflating: OTROS/n02086240_739.jpg
#   inflating: OTROS/n02086240_7404.jpg
#   inflating: OTROS/n02086240_745.jpg
#   inflating: OTROS/n02086240_7454.jpg
#   inflating: OTROS/n02086240_756.jpg
#   inflating: OTROS/n02086240_762.jpg
#   inflating: OTROS/n02086240_7728.jpg
#   inflating: OTROS/n02086240_788.jpg
#   inflating: OTROS/n02086240_789.jpg
#   inflating: OTROS/n02086240_7954.jpg
#   inflating: OTROS/n02086240_818.jpg
#   inflating: OTROS/n02086240_8489.jpg
#   inflating: OTROS/n02086240_8812.jpg
#   inflating: OTROS/n02086240_8825.jpg
#   inflating: OTROS/n02086240_9.jpg
#   inflating: OTROS/n02086240_9098.jpg
#   inflating: OTROS/n02086240_9293.jpg
#   inflating: OTROS/n02086240_936.jpg
#   inflating: OTROS/n02086240_9429.jpg
#   inflating: OTROS/n02086240_9467.jpg
#   inflating: OTROS/n02086240_9551.jpg
#   inflating: OTROS/n02086240_963.jpg
#   inflating: OTROS/n02086240_968.jpg
#   inflating: OTROS/n02086240_9750.jpg
#   inflating: OTROS/n02097047_5223.jpg
#   inflating: OTROS/n02097047_5253.jpg
#   inflating: OTROS/n02097047_5257.jpg
#   inflating: OTROS/n02097047_5308.jpg
#   inflating: OTROS/n02097047_535.jpg
#   inflating: OTROS/n02097047_5581.jpg
#   inflating: OTROS/n02097047_5644.jpg
#   inflating: OTROS/n02097047_581.jpg
#   inflating: OTROS/n02097047_60.jpg
#   inflating: OTROS/n02097047_610.jpg
#   inflating: OTROS/n02097047_6203.jpg
#   inflating: OTROS/n02097047_6328.jpg
#   inflating: OTROS/n02097047_635.jpg
#   inflating: OTROS/n02097047_6434.jpg
#   inflating: OTROS/n02097047_6503.jpg
#   inflating: OTROS/n02097047_6534.jpg
#   inflating: OTROS/n02097047_6553.jpg
#   inflating: OTROS/n02097047_6567.jpg
#   inflating: OTROS/n02097047_6627.jpg
#   inflating: OTROS/n02097047_6701.jpg
#   inflating: OTROS/n02097047_674.jpg
#   inflating: OTROS/n02097047_6744.jpg
#   inflating: OTROS/n02097047_6813.jpg
#   inflating: OTROS/n02097047_6836.jpg
#   inflating: OTROS/n02097047_6884.jpg
#   inflating: OTROS/n02097047_6936.jpg
#   inflating: OTROS/n02097047_724.jpg
#   inflating: OTROS/n02097047_728.jpg
#   inflating: OTROS/n02097047_73.jpg
#   inflating: OTROS/n02097047_731.jpg
#   inflating: OTROS/n02097047_752.jpg
#   inflating: OTROS/n02097047_834.jpg
#   inflating: OTROS/n02097047_946.jpg
#   inflating: OTROS/n02097047_951.jpg
#   inflating: OTROS/n02105855_15820.jpg
#   inflating: OTROS/n02105855_17401.jpg
#   inflating: OTROS/n02105855_17517.jpg
#   inflating: OTROS/n02105855_17706.jpg
#   inflating: OTROS/n02105855_17893.jpg
#   inflating: OTROS/n02105855_18141.jpg
#   inflating: OTROS/n02105855_18288.jpg
#   inflating: OTROS/n02105855_18293.jpg
#   inflating: OTROS/n02105855_18443.jpg
#   inflating: OTROS/n02105855_18496.jpg
#   inflating: OTROS/n02105855_18564.jpg
#   inflating: OTROS/n02105855_18782.jpg
#   inflating: OTROS/n02105855_19002.jpg
#   inflating: OTROS/n02105855_742.jpg
#   inflating: OTROS/n02105855_7495.jpg
#   inflating: OTROS/n02105855_7527.jpg
#   inflating: OTROS/n02105855_7560.jpg
#   inflating: OTROS/n02105855_7607.jpg
#   inflating: OTROS/n02105855_7612.jpg
#   inflating: OTROS/n02105855_7708.jpg
#   inflating: OTROS/n02105855_7717.jpg
#   inflating: OTROS/n02105855_9079.jpg
#   inflating: OTROS/n02105855_9093.jpg
#   inflating: OTROS/n02105855_9277.jpg
#   inflating: OTROS/n02105855_9293.jpg
#   inflating: OTROS/n02105855_9415.jpg
#   inflating: OTROS/n02105855_9689.jpg
#   inflating: OTROS/n02105855_982.jpg
#   inflating: OTROS/n02105855_9857.jpg
#   inflating: OTROS/n02105855_9903.jpg
#   inflating: OTROS/n02108915_759.jpg
#   inflating: OTROS/n02108915_7608.jpg
#   inflating: OTROS/n02108915_7806.jpg
#   inflating: OTROS/n02108915_7883.jpg
#   inflating: OTROS/n02108915_8258.jpg
#   inflating: OTROS/n02108915_8425.jpg
#   inflating: OTROS/n02108915_8604.jpg
#   inflating: OTROS/n02108915_8696.jpg
#   inflating: OTROS/n02108915_8923.jpg
#   inflating: OTROS/n02108915_895.jpg
#   inflating: OTROS/n02108915_9125.jpg
#   inflating: OTROS/n02108915_9202.jpg
#   inflating: OTROS/n02108915_9399.jpg
#   inflating: OTROS/n02108915_971.jpg
#   inflating: OTROS/n02108915_977.jpg
#   inflating: OTROS/n02108915_9804.jpg
#   inflating: OTROS/n02108915_9899.jpg
#   inflating: OTROS/n02109961_6020.jpg
#   inflating: OTROS/n02109961_6119.jpg
#   inflating: OTROS/n02109961_623.jpg
#   inflating: OTROS/n02109961_630.jpg
#   inflating: OTROS/n02109961_658.jpg
#   inflating: OTROS/n02109961_8353.jpg
#   inflating: OTROS/n02109961_843.jpg
#   inflating: OTROS/n02109961_853.jpg
#   inflating: OTROS/n02109961_8698.jpg
#   inflating: OTROS/n02109961_8835.jpg
#   inflating: OTROS/n02109961_8845.jpg
#   inflating: OTROS/n02109961_8977.jpg
#   inflating: OTROS/n02109961_930.jpg
#   inflating: OTROS/n02109961_9348.jpg
#   inflating: OTROS/n02109961_9765.jpg
#   inflating: OTROS/n02109961_977.jpg
#   inflating: OTROS/n02109961_997.jpg
#   inflating: OTROS/n02109961_9973.jpg
#   inflating: OTROS/samoyed_40.jpg
#   inflating: OTROS/samoyed_41.jpg
#   inflating: OTROS/samoyed_42.jpg
#   inflating: OTROS/samoyed_43.jpg
#   inflating: OTROS/samoyed_44.jpg
#   inflating: OTROS/samoyed_45.jpg
#   inflating: OTROS/samoyed_5.jpg
#   inflating: OTROS/samoyed_57.jpg
#   inflating: OTROS/samoyed_58.jpg
#   inflating: OTROS/samoyed_59.jpg
#   inflating: OTROS/samoyed_6.jpg
#   inflating: OTROS/samoyed_60.jpg
#   inflating: OTROS/samoyed_61.jpg
#   inflating: OTROS/samoyed_62.jpg
#   inflating: OTROS/samoyed_63.jpg
#   inflating: OTROS/samoyed_64.jpg
#   inflating: OTROS/samoyed_65.jpg
#   inflating: OTROS/samoyed_66.jpg
#   inflating: OTROS/samoyed_67.jpg
#   inflating: OTROS/samoyed_68.jpg
#   inflating: OTROS/samoyed_69.jpg
#   inflating: OTROS/samoyed_7.jpg
#   inflating: OTROS/samoyed_70.jpg
#   inflating: OTROS/samoyed_71.jpg
#   inflating: OTROS/samoyed_72.jpg
#   inflating: OTROS/samoyed_73.jpg
#   inflating: OTROS/samoyed_74.jpg
#   inflating: OTROS/samoyed_75.jpg
#   inflating: OTROS/samoyed_76.jpg
#   inflating: OTROS/samoyed_77.jpg
#   inflating: OTROS/samoyed_78.jpg
#   inflating: OTROS/samoyed_79.jpg
#   inflating: OTROS/samoyed_8.jpg
#   inflating: OTROS/samoyed_80.jpg
#   inflating: OTROS/samoyed_81.jpg
#   inflating: OTROS/samoyed_82.jpg
#   inflating: OTROS/samoyed_83.jpg
#   inflating: OTROS/samoyed_84.jpg
#   inflating: OTROS/samoyed_85.jpg
#   inflating: OTROS/samoyed_86.jpg
#   inflating: OTROS/samoyed_87.jpg
#   inflating: OTROS/samoyed_88.jpg
#   inflating: OTROS/samoyed_89.jpg
#   inflating: OTROS/samoyed_9.jpg
#   inflating: OTROS/samoyed_90.jpg
#   inflating: OTROS/samoyed_91.jpg
#   inflating: OTROS/samoyed_92.jpg
#   inflating: OTROS/samoyed_93.jpg
#   inflating: OTROS/samoyed_94.jpg
#   inflating: OTROS/samoyed_95.jpg
#   inflating: OTROS/samoyed_96.jpg
#   inflating: OTROS/samoyed_97.jpg
#   inflating: OTROS/samoyed_98.jpg
#   inflating: OTROS/samoyed_99.jpg
#   inflating: OTROS/shiba_inu_84.jpg
#   inflating: OTROS/shiba_inu_85.jpg
#   inflating: OTROS/shiba_inu_86.jpg
#   inflating: OTROS/shiba_inu_87.jpg
#   inflating: OTROS/shiba_inu_88.jpg
#   inflating: OTROS/shiba_inu_89.jpg
#   inflating: OTROS/shiba_inu_9.jpg
#   inflating: OTROS/shiba_inu_90.jpg
#   inflating: OTROS/shiba_inu_91.jpg
#   inflating: OTROS/shiba_inu_92.jpg
#   inflating: OTROS/shiba_inu_93.jpg
#   inflating: OTROS/shiba_inu_94.jpg
#   inflating: OTROS/shiba_inu_95.jpg
#   inflating: OTROS/shiba_inu_96.jpg
#   inflating: OTROS/shiba_inu_97.jpg
#   inflating: OTROS/shiba_inu_98.jpg
#   inflating: OTROS/shiba_inu_99.jpg
# /content

# %%
#eliminar la basura (ZIP)

# !rm -rf  /content/pug/PUG.zip
# !rm -rf /content/beagle/BEAGLE.zip
# !rm -rf /content/otros/OTROS.zip

# %%
#cuantas imagenes tiene cada carpeta

# !ls /content/beagle | wc -l #395
# !ls /content/pug | wc -l #400
# !ls /content/otros/OTROS | wc -l #400
# Out:
# 395
# 400
# 498

# %%
#ver ejemplos de las imagenes con pyplot
import os
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

plt.figure(figsize=(15,15))

carpeta = '/content/beagle'
imagenes = os.listdir(carpeta)

for i, nombreimg in enumerate(imagenes[:36]):
  plt.subplot(6,6,i+1)
  imagen = mpimg.imread(carpeta + '/' + nombreimg)
  plt.imshow(imagen)

# %%
#ver ejemplos de las imagenes con pyplot
import os
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

plt.figure(figsize=(15,15))

carpeta = '/content/pug'
imagenes = os.listdir(carpeta)

for i, nombreimg in enumerate(imagenes[:25]):
  plt.subplot(5,5,i+1)
  imagen = mpimg.imread(carpeta + '/' + nombreimg)
  plt.imshow(imagen)

# %%
#Crear carpetas para hacer el set de datos

# !mkdir dataset
# !mkdir dataset/pug
# !mkdir dataset/beagle
# !mkdir dataset/otros

# %%
#Copiar imagenes que subimos a carpetas del dataset
#Limitar para que todos tengan la misma cantidad de imagenes
#maximo 395 (el num. menor de imagenes que se tiene)

import shutil
carpeta_fuente = '/content/beagle'
carpeta_destino = '/content/dataset/beagle'

imagenes = os.listdir(carpeta_fuente)

for i, nombreimg in enumerate(imagenes):
  if i < 395:
    #Copia de la carpeta fuente a la destino
    shutil.copy(carpeta_fuente + '/' + nombreimg, carpeta_destino + '/' + nombreimg)

# %%
#Copiar imagenes que subimos a carpetas del dataset
#Limitar para que todos tengan la misma cantidad de imagenes
#maximo 395 (el num. menor de imagenes que se tiene)

import shutil
carpeta_fuente = '/content/pug'
carpeta_destino = '/content/dataset/pug'

imagenes = os.listdir(carpeta_fuente)

for i, nombreimg in enumerate(imagenes):
  if i < 395:
    #Copia de la carpeta fuente a la destino
    shutil.copy(carpeta_fuente + '/' + nombreimg, carpeta_destino + '/' + nombreimg)

# %%
import shutil
carpeta_fuente = '/content/otros/OTROS'
carpeta_destino = '/content/dataset/otros'

imagenes = os.listdir(carpeta_fuente)

for i, nombreimg in enumerate(imagenes):
  if i < 395:
    #Copia de la carpeta fuente a la destino
    shutil.copy(carpeta_fuente + '/' + nombreimg, carpeta_destino + '/' + nombreimg)

# %%
#Mostrar cuantas imagenes tengo de cada categoria en el dataset
# !ls /content/dataset/pug/ | wc -l
# !ls /content/dataset/beagle | wc -l
# !ls /content/dataset/otros | wc -l
# Out:
# 395
# 395
# 395

# %%
#Aumento de datos con ImageDataGenerator
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import numpy as np

#Crear el dataset generador
datagen = ImageDataGenerator(
    rescale=1. / 255,
    rotation_range = 30,
    width_shift_range = 0.25,
    height_shift_range = 0.25,
    shear_range = 15,
    zoom_range = [0.5, 1.5],
    validation_split=0.24 #20% para pruebas
)

#Generadores para sets de entrenamiento y pruebas
data_gen_entrenamiento = datagen.flow_from_directory('/content/dataset', target_size=(224,224),
                                                     batch_size=128, shuffle=True, subset='training')
data_gen_pruebas = datagen.flow_from_directory('/content/dataset', target_size=(224,224),
                                                     batch_size=128, shuffle=True, subset='validation')

#Imprimir 10 imagenes del generador de entrenamiento
for imagen, etiqueta in data_gen_entrenamiento:
  for i in range(10):
    plt.subplot(2,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.imshow(imagen[i])
  break
plt.show()
# Out:
# Found 903 images belonging to 3 classes.
# Found 282 images belonging to 3 classes.

# %%
import tensorflow as tf
import tensorflow_hub as hub
#importe de mobilenet v2
url = "https://tfhub.dev/google/tf2-preview/mobilenet_v2/feature_vector/4"
mobilenetv2 = hub.KerasLayer(url, input_shape=(224,224,3))

# %%
#Congelar el modelo descargado
mobilenetv2.trainable = False

# %%
#Creando el modelo
modelo = tf.keras.Sequential([
    mobilenetv2,
    tf.keras.layers.Dense(3, activation='softmax')
])

# %%
#Resumen del modelo
modelo.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  keras_layer (KerasLayer)    (None, 1280)              2257984
#
#  dense (Dense)               (None, 3)                 3843
#
# =================================================================
# Total params: 2261827 (8.63 MB)
# Trainable params: 3843 (15.01 KB)
# Non-trainable params: 2257984 (8.61 MB)
# _________________________________________________________________

# %%
#Compilar como siempre
learning_rate = 0.29  # aun no se pero menos de 0,1 no sirve
optimizer = tf.keras.optimizers.Adam(learning_rate=learning_rate)
modelo.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# %%
#Entrenar el modelo
EPOCAS = 20

historial = modelo.fit(
    data_gen_entrenamiento, epochs=EPOCAS, batch_size=1536, #entre 700 y 1000 puede estar el resultado o un poco menos talvez
    validation_data=data_gen_pruebas
)
# Out:
# Epoch 1/20
# 8/8 [==============================] - 20s 3s/step - loss: 0.0805 - accuracy: 0.9712 - val_loss: 0.3035 - val_accuracy: 0.8901
# Epoch 2/20
# 8/8 [==============================] - 20s 2s/step - loss: 0.0720 - accuracy: 0.9734 - val_loss: 0.3395 - val_accuracy: 0.8865
# Epoch 3/20
# 8/8 [==============================] - 18s 2s/step - loss: 0.0745 - accuracy: 0.9723 - val_loss: 0.3382 - val_accuracy: 0.8794
# Epoch 4/20
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-35-43d1af78d268> in <cell line: 4>()
#       2 EPOCAS = 20
#       3
# ----> 4 historial = modelo.fit(
#       5     data_gen_entrenamiento, epochs=EPOCAS, batch_size=1536, #entre 700 y 1000 puede estar el resultado o un poco menos talvez
#       6     validation_data=data_gen_pruebas
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      63         filtered_tb = None
#      64         try:
# ---> 65             return fn(*args, **kwargs)
#      66         except Exception as e:
#      67             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1805                         ):
#    1806                             callbacks.on_train_batch_begin(step)
# -> 1807                             tmp_logs = self.train_function(iterator)
#    1808                             if data_handler.should_sync:
#    1809                                 context.async_wait()
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in __call__(self, *args, **kwds)
#     830
#     831       with OptionalXlaContext(self._jit_compile):
# --> 832         result = self._call(*args, **kwds)
#     833
#     834       new_tracing_count = self.experimental_get_tracing_count()
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in _call(self, *args, **kwds)
#     866       # In this case we have created variables on the first call, so we run the
#     867       # defunned version which is guaranteed to never create variables.
# --> 868       return tracing_compilation.call_function(
#     869           args, kwds, self._no_variable_creation_config
#     870       )
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py in call_function(args, kwargs, tracing_options)
#     137   bound_args = function.function_type.bind(*args, **kwargs)
#     138   flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139   return function._call_flat(  # pylint: disable=protected-access
#     140       flat_inputs, captured_inputs=function.captured_inputs
#     141   )
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/concrete_function.py in _call_flat(self, tensor_inputs, captured_inputs)
#    1321         and executing_eagerly):
#    1322       # No tape is watching; skip to running the function.
# -> 1323       return self._inference_function.call_preflattened(args)
#    1324     forward_backward = self._select_forward_and_backward_functions(
#    1325         args,
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py in call_preflattened(self, args)
#     214   def call_preflattened(self, args: Sequence[core.Tensor]) -> Any:
#     215     """Calls with flattened tensor inputs and returns the structured output."""
# --> 216     flat_outputs = self.call_flat(*args)
#     217     return self.function_type.pack_output(flat_outputs)
#     218
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py in call_flat(self, *args)
#     249         with record.stop_recording():
#     250           if self._bound_context.executing_eagerly():
# --> 251             outputs = self._bound_context.call_function(
#     252                 self.name,
#     253                 list(args),
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/context.py in call_function(self, name, tensor_inputs, num_outputs)
#    1484     cancellation_context = cancellation.context()
#    1485     if cancellation_context is None:
# -> 1486       outputs = execute.execute(
#    1487           name.decode("utf-8"),
#    1488           num_outputs=num_outputs,
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51   try:
#      52     ctx.ensure_initialized()
# ---> 53     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                         inputs, attrs, num_outputs)
#      55   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
#Graficas de precisión
acc = historial.history['accuracy']
val_acc = historial.history['val_accuracy']

loss = historial.history['loss']
val_loss = historial.history['val_loss']

rango_epocas = range(20)

plt.figure(figsize=(8,8))
plt.subplot(1,2,1)
plt.plot(rango_epocas, acc, label='Precisión Entrenamiento')
plt.plot(rango_epocas, val_acc, label='Precisión Pruebas')
plt.legend(loc='lower right')
plt.title('Precisión de entrenamiento y pruebas')

plt.subplot(1,2,2)
plt.plot(rango_epocas, loss, label='Pérdida de entrenamiento')
plt.plot(rango_epocas, val_loss, label='Pérdida de pruebas')
plt.legend(loc='upper right')
plt.title('Pérdida de entrenamiento y pruebas')
plt.show()

# %%
#Categorizar una imagen de internet PREDICCION
from PIL import Image
import requests
from io import BytesIO
import cv2

def categorizarURL(url):
  respuesta = requests.get(url)
  img = Image.open(BytesIO(respuesta.content))
  img = np.array(img).astype(float)/255

  img = cv2.resize(img, (224,224))
  prediccion = modelo.predict(img.reshape(-1, 224, 224, 3))
  return np.argmax(prediccion[0], axis=-1)

def categorizarIMG(img):
  img = Image.open(img)
  img = np.array(img).astype(float)/255

  img = cv2.resize(img, (224,224))
  prediccion = modelo.predict(img.reshape(-1, 224, 224, 3))
  return np.argmax(prediccion[0], axis=-1)

# %%
#Categorizar una imagen de internet PROBABILIDADES
def categorizar1_PURL(url):
    respuesta = requests.get(url)
    img = Image.open(BytesIO(respuesta.content))
    img = np.array(img).astype(float) / 255

    img = cv2.resize(img, (224, 224))
    #sacar porcentaje
    probabilidades = modelo.predict(img.reshape(-1, 224, 224, 3))[0]
    return probabilidades

def categorizar1_PIMG(img):
    img = Image.open(img)
    img = np.array(img).astype(float) / 255

    img = cv2.resize(img, (224, 224))
    probabilidades = modelo.predict(img.reshape(-1, 224, 224, 3))[0]
    return probabilidades

# %%
from google.colab import output
output.enable_custom_widget_manager()

# %%
from google.colab import output
output.enable_custom_widget_manager()

# %%
from IPython.display import display, Javascript
from google.colab.output import eval_js
from base64 import b64decode

# Función para capturar una imagen desde la cámara
def take_photo(filename='Foto.jpg', quality=1):
    js = Javascript('''
        async function takePhoto(quality) {
            const div = document.createElement('div');
            const capture = document.createElement('button');
            capture.textContent = 'Tomar foto';
            div.appendChild(capture);

            const video = document.createElement('video');
            video.style.display = 'block';
            const stream = await navigator.mediaDevices.getUserMedia({video: true});

            document.body.appendChild(div);
            div.appendChild(video);
            video.srcObject = stream;
            await video.play();

            // Redimensionar el elemento video para adaptarlo al ancho de la celda de salida en Colab
            google.colab.output.setIframeHeight(document.documentElement.scrollHeight, true);

            // Esperar a que se haga clic en el botón de captura
            await new Promise((resolve) => capture.onclick = resolve);

            const canvas = document.createElement('canvas');
            canvas.width = video.videoWidth;
            canvas.height = video.videoHeight;
            canvas.getContext('2d').drawImage(video, 0, 0);
            stream.getVideoTracks()[0].stop();
            div.remove();

            return canvas.toDataURL('image/jpeg', quality);
        }
    ''')
    display(js)

    data = eval_js('takePhoto({})'.format(quality))
    binary_data = b64decode(data.split(',')[1])

    with open(filename, 'wb') as f:
        f.write(binary_data)

    return filename

# Capturar una foto y mostrarla
photo = take_photo()
print('Foto tomada:', photo)

# %%
from IPython.display import display, HTML, Javascript
from google.colab.output import eval_js
from base64 import b64decode

def capture_image(filename='Foto.jpg', quality=1):
    # HTML y JavaScript para la interfaz de usuario
    html_code = '''
    <div>
        <video id="video" autoplay style="display:block; width:100%; max-width:500px;"></video>
        <button id="capture">Tomar foto</button>
        <button id="stop" style="display:none;">Detener cámara</button>
    </div>
    <canvas style="display:none;"></canvas>
    <p id="message"></p>
    '''

    display(HTML(html_code))

    # JavaScript para controlar la cámara y la captura de fotos
    js_code = '''
    const video = document.getElementById('video');
    const captureButton = document.getElementById('capture');
    const stopButton = document.getElementById('stop');
    const canvas = document.querySelector('canvas');
    const ctx = canvas.getContext('2d');
    const message = document.getElementById('message');

    async function setupCamera() {
        const stream = await navigator.mediaDevices.getUserMedia({ 'video': true });
        video.srcObject = stream;
        await video.play();
    }

    setupCamera();

    function takeSnapshot() {
        canvas.width = video.videoWidth;
        canvas.height = video.videoHeight;
        ctx.drawImage(video, 0, 0, canvas.width, canvas.height);
        return canvas.toDataURL('image/jpeg', ''' + str(quality) + ''');
    }

    captureButton.addEventListener('click', async () => {
        const imgData = takeSnapshot();
        const binaryData = atob(imgData.split(',')[1]);
        const dataArray = new Uint8Array(binaryData.length);
        for (let i = 0; i < binaryData.length; i++) {
            dataArray[i] = binaryData.charCodeAt(i);
        }

        // Crear un archivo Blob y guardar la imagen localmente
        const blob = new Blob([dataArray], { type: 'image/jpeg' });
        const url = URL.createObjectURL(blob);

        // Crear un enlace de descarga
        const a = document.createElement('a');
        a.href = url;
        a.download = 'captured.jpg';
        a.style.display = 'none';
        document.body.appendChild(a);
        a.click();
        window.URL.revokeObjectURL(url);

        captureButton.style.display = 'none';
        stopButton.style.display = 'block';
        message.innerText = 'Foto tomada. Haga clic en "Detener cámara" cuando haya terminado.';
    });

    stopButton.addEventListener('click', () => {
        const stream = video.srcObject;
        const tracks = stream.getTracks();
        tracks.forEach(track => track.stop());

        captureButton.style.display = 'block';
        stopButton.style.display = 'none';
        message.innerText = 'Cámara detenida. Puede tomar otra foto si lo desea.';
    });
    '''

    display(Javascript(js_code))

capture_image()

# %%
"""CAMARA CON JS"""
#CAMARA FUNCIONAL ULTIMA VERSION

from IPython.display import display, Javascript
from google.colab.output import eval_js
from base64 import b64decode
import ipywidgets as widgets

# Variables globales para controlar la cámara
use_front_camera = True

# Función para alternar entre las cámaras
def toggle_camera(change):
    global use_front_camera
    use_front_camera = not use_front_camera

# Función para capturar una imagen desde la cámara
def take_photo(filename='photo.jpg', quality=0.8):
    js = Javascript('''
        async function takePhoto(quality, useFrontCamera) {
            const div = document.createElement('div');
            const capture = document.createElement('button');
            const toggle = document.createElement('button');
            capture.textContent = 'Tomar foto';
            toggle.textContent = 'Cambiar cámara';
            div.appendChild(capture);
            div.appendChild(toggle);

            const video = document.createElement('video');
            video.style.display = 'block';
            const constraints = {
                video: {
                    facingMode: useFrontCamera ? 'user' : 'environment'
                }
            };
            const stream = await navigator.mediaDevices.getUserMedia(constraints);

            document.body.appendChild(div);
            div.appendChild(video);
            video.srcObject = stream;
            await video.play();

            // Redimensionar el elemento video para adaptarlo al ancho de la celda de salida en Colab
            google.colab.output.setIframeHeight(document.documentElement.scrollHeight, true);

            // Esperar a que se haga clic en el botón de captura
            await new Promise((resolve) => capture.onclick = resolve);

            const canvas = document.createElement('canvas');
            canvas.width = video.videoWidth;
            canvas.height = video.videoHeight;
            canvas.getContext('2d').drawImage(video, 0, 0);
            stream.getVideoTracks()[0].stop();
            div.remove();

            return canvas.toDataURL('image/jpeg', quality);
        }
    ''')
    display(js)

    data = eval_js('takePhoto({}, {})'.format(quality, str(use_front_camera).lower()))
    binary_data = b64decode(data.split(',')[1])

    with open(filename, 'wb') as f:
        f.write(binary_data)

    return filename

# Agregar un botón para cambiar de cámara
toggle_button = widgets.Button(description="Cambiar cámara")
toggle_button.on_click(toggle_camera)

# Capturar una foto usando la cámara frontal por defecto
photo = take_photo()
print('Foto tomada:', photo)

# Mostrar el botón de cambio de cámara
display(toggle_button)
# Out:
# Foto tomada: photo.jpg
# Button(description='Cambiar cámara', style=ButtonStyle())

# %%
from PIL import Image
from IPython.display import display

# Cargar la imagen capturada
image = Image.open('photo.jpg')

# Mostrar la imagen
display(image)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x480>

# %%
textoB = """
Beagle cachorro:
Para educar un Beagle cachorro, se necesita que se haga por medio de juegos, enseñándole que sus necesidades no se hacen dentro de casa y
usando juguetes cuando quiera morder los muebles. Te podrás comunicar con tu cachorro usando distintos tonos de voz, aullidos o sonidos,
ya que, los cachorros intentan imitar los sonidos.

Necesidades:
• Higiene: Elegir antiparásitos adecuados para el cachorro, una infección puede ser mortal. También es importante la limpieza corporal y dental,
por lo cual, es importante tener un champú y crema dental adecuados, así mismo, la limpieza correcta de los oídos es esencial, para evitar infecciones auditivas.
• Alimentación: Necesita pienso de alta calidad específico para cachorros, saludable y sabroso o una dieta casera adaptada para su edad, actividad, etc. Debe ser
el adecuado para las necesidades nutricionales que tiene con el objetivo de crecer fuerte y sano.
• Cama: Es importante que el cachorro tenga donde dormir, de esta forma, se acostumbrará al espacio. Hay que tener en cuenta que debe tener un poco de intimidad y
 que esté cerca del entorno familiar.
• Comedero y bebedero: Deben ser del tamaño del cachorro. Si no estarás mucho en casa, es importante tener comederos automáticos.
• Paseos: Es esencial tener un arnés y correa para dar paseos con el cachorro, también es necesario un trasportín para las visitas al veterinario. Y finalmente,
se recomienda ponerle un microchip, ya que, es muy funcional en caso de que se pierda.
• Entretenimiento: Hay juguetes especiales para cachorros que son suaves y con los que se le pueden enseñar a comportarse.
• Vacunación: La primera dosis debe ser administrada a los 45 días tras su nacimiento, un refuerzo a los 15-20 días y de nuevo cada 20 o 30 días,
en total 4 dosis. Al medio año se vuelve a dar un refuerzo y, por último, una vez al año durante toda su vida.

Beagle adulto:
Hay que tener en cuenta que lo más común en un Beagle es la infección de oído que puede tener, esto, en los casos más graves, puede provocar sordera.
También es común que padezca de problemas oculares, como cataratas o glaucoma, donde puede perder paulatinamente la visión.
Necesidades:
• Alimentación: las raciones de comida deben ser controladas y necesita hacer ejercicio para no tener sobrepeso. Se recomienda un pienso de alto
contenido en fibra para que regule su tránsito intestinal. Si el animal tiene unos kilos de más, opta por un pienso light, una alimentación con
comida casera enfocada a ayudarle a perder peso de forma sana.
• Ejercicio: Es necesario que haga mucho ejercicio, esto con el fin de que este sano de forma física y mental. Es importante sacarlo 3 veces al día
o hacer salidas largas (1 hora y media), si no tiene mucho espacio dentro de casa
• Higiene: Se debe procurar cepillar su pelaje entre 2 y 3 veces a la semana y que tenga baño una vez al mes. Con relación a las orejas, es importante
revisarlas constantemente y limpiarlas.
• Socialización: Es importante enseñarlo a convivir con otros perros para que tenga una buena socialización. Así mismo, el Beagle es muy apegado a la familia,
por lo que es importante educarlo para que no sienta mucho este vacío, ya que, puede sufrir de ansiedad por el tiempo que permanezca lejos de ti.
• Baños: Durante el baño es muy importante eliminar todo el pelo muerto, por lo que podemos cepillarlos antes del baño y tener especial cuidado con sus oídos,
ya que pueden infectarse si les entra agua, algo muy común por sus orejas grandes.
• Vacunación: Al medio año se da un refuerzo y, por último, una vez al año durante toda su vida.

Beagle Senior – anciano:
Si tienes un perro mayor, es normal que empieces a notar que se está volviendo más lento y menos activo.
Necesidades:
• Alimentación: Se recomienda bajar la cantidad de energía que se suministra a través de la dieta para impedir que tenga sobrepeso. Además, los perros más mayores
reducen su capacidad de sentir el sabor y el aroma de los alimentos, por lo que las comidas sabrosas pueden ser una ventaja incluso para los Beagle.
• Ejercicio: Es importante que tu perro haga ejercicio regularmente para mantenerse saludable. Sin embargo, al ser un perro mayor, es mejor que le proporciones ejercicio
moderado y adaptado a sus necesidades. Puedes darle paseos cortos y suaves o jugar con él en casa con juguetes que no requieran demasiada actividad física.
• Juegos: Es importante hacerle juegos mentales, ya que, los juegos mentales son una excelente manera de estimular la mente de tu perro y mantenerlo activo. Puedes enseñarle
nuevos trucos o jugar a juegos de búsqueda que le permitan utilizar su olfato para encontrar premios.
• Ser constante en las visitas al veterinario.
• Ambiente: El ambiente en que conviven los perros mayores, debe ser cómodo y tranquilo, el animal se debe sentir seguro, también, debe estar limpio.
• Necesita de cuidados más especializados, más atención y mucho cariño.
"""

# %%
textoP = """
Pug cachorro:
Al cuidar a su perro cuando es un bebé, puede prevenir problemas de salud y comportamiento más adelante, haciendo que sus vidas sean más fáciles.

Necesidades:
•	Educación: Los Pugs son una raza especialmente testaruda, y cualquiera que sea el comportamiento que estimules como cachorro, se mantendrá hasta la edad adulta.
•	Higiene: Cada día, limpie suavemente sus pliegues faciales con una almohadilla medicada suave o un hisopo de algodón húmedo y cálido. Esto evita la suciedad y
las bacterias que pueden causar infecciones o enfermar a su cachorro.
•	Comedero: Es importante que estén elevados, ya que, cuando se inclinan a tomar agua o a comer, pueden volcarse y esto puede ser muy peligroso.
•	Temperatura: Son sensibles a la temperatura a cualquier edad, pero cuando son cachorros las temperaturas extremas son un riesgo grave para su salud, pueden tener
dificultad para respirar en lugares cálidos y fríos y son susceptibles a los resfriados y la neumonía cuando no están protegidos de la intemperie helada. Asegúrate de
que tenga un suéter que pueda usar cuando la temperatura baje y si hay calor o humedad, mantenlo en un ambiente con temperatura controlada a menos que tenga que hacer
sus necesidades al aire libre.
•	Paseos: Camina con tu cachorro poniéndole un arnés en lugar de usar un collar. A causa de sus caras planas, los Pugs pueden presentar dificultad para respirar
adecuadamente, por lo que los collares tradicionales representan una amenaza para su salud. Los arneses son preferibles para esta raza.
•	Ejercicio: Deben realizar muchos ejercicios que les permita liberar el estrés y desarrollar sus extremidades. Los primeros años de ejercicios en la vida del Pug
determinaran los últimos años de este.

Pug adulto:
El pug tiene el perfecto comportamiento de un perro de compañía, cariñoso, alegre, vivaz, apegado a su familia. Suelen tener una gran tendencia a llamar la atención,
pero no son excesivamente traviesos.

Necesidades:
•	Cepillado: Cepillar su pelo una o dos veces por semana, para mantener su pelaje sano y brillante, libre de suciedad y pelos muertos.
•	Limpieza: Limpia sus arrugas con un paño húmedo y sécalas a conciencia para evitar la aparición de hongos y otras infecciones cutáneas. El aseo de las orejas del
perro Pug también es esencial. Estamos hablando de perros a los cuales se les acumula suciedad en las orejas con bastante facilidad, por lo menos cada 2 semanas.
•	Paseos: No debemos exigir a los perros de raza Pug un ejercicio muy intenso. Realiza paseos moderados un par de veces al día, complementados con juegos adecuados
dentro o fuera de casa son suficientes para satisfacer las necesidades físicas de nuestro perro Pug.
•	Enfermedades: Conviene destacar su principal problema, el hocico corto, puede afectar negativamente a la salud del Pug. Algunas patologías relacionadas con esto
son problemas respiratorios, paladar elongado, narinas estenóticas, luxación patelar, entropión y enfermedad de Legg-Calve_perthes. Por otro lado, ocasionalmente
presentan casos de epilepsia y también lesiones oculares, esto último debido a sus saltones ojos.

Pug senior – anciano:
Conforme vaya avanzando en su edad podrás apreciar en tu mascota una serie de cambios en su aspecto físico como el cambio en pelaje, se volverá opaco y se caerá
fácilmente, su piel reseca, el hocico se torna de color gris, disminución de energía general, querrá estar más tiempo dormido, rigidez en sus articulaciones,
problemas con su dentadura, disminución auditiva gradual y sus ojos con «niebla», disminución visual.

Necesidades:
•	Hábitos: Trata de mantener sus hábitos en la medida de lo posible, quizá requiera unos ajustes, pero no por ser viejito lo consientas demasiado impidiéndole hacer
cosas que aun pueda hacer.
•	Alimentación: Con la edad tu perrito Pug verá afectada su dentadura, tendrá desgaste e incluso perdida de piezas dentales, en consecuencia, a tu Pug le costará
trabajo masticar sus croquetas duras, un ajuste de dieta será necesario incorporando dieta blanda a su alimentación, claro está recuerda que siempre que realices un
cambio en su dieta, hazlo gradualmente.
•	Movilidad: Conforme aumente su edad quizá tengas que hacer paseos más cortos, aunque con mayor frecuencia; también se cansará más rápidamente, así que será
necesario hacer pequeñas pausas a los paseos. Será recomendable comenzar los paseos a un paso lento, a modo de calentamiento, por unos 10 minutos y luego aumentar el
ritmo, para finalmente disminuir nuevamente el ritmo hasta volver a casa.
•	Higiene: Una de las cosas que les pasas con la edad a los Pug es que su piel se reseca, así que no dudes en consultar con tu veterinario para que te recomiende
alguna crema o suplemento alimenticio que permita mantener su piel en buen estado. Otra situación que ocurre en la piel de los Pug viejitos es que los cuerpos
pilosos se vuelven más débiles y eso ocasiona que el pelo se le caiga más fácilmente, por lo que sería importante mantener rutina de cepillado, aunque por tiempos
más cortos, Hacer más esporádico el baño y Mantener hidratada su piel.
•	Temperatura: Los cambios bruscos de temperatura le pueden afectar, así que procura evitar que tu mascota pase de espacios cálidos a ambientes fríos, sobre todo
en la temporada invernal.

"""

# %%
#0 = beagle, 1 = otros, 2 = pug
#prediccion IMAGEN url
url = 'https://www.elfinanciero.com.mx/resizer/D9N419lRzyUG0wM4u-LFRx4zoBk=/1440x810/filters:format(jpg):quality(70)/cloudfront-us-east-1.images.arcpublishing.com/elfinanciero/ELE6TQ3K6BFTZPLZ3VPRCOXKPE.jpeg' #debe ser 1
prediccion = categorizarURL(url)
probabilidades = categorizar1_PURL(url)
tipo = ""

probabilidades_porcentuales = [p * 100 for p in probabilidades]
probabilidades_formateadas = [f"{p:.2f}%" for p in probabilidades_porcentuales]

response = requests.get(url, stream=True)
img = Image.open(response.raw)

nuevo_ancho = 400
img_redimensionada = img.resize((nuevo_ancho, int(img.height * (nuevo_ancho / img.width))))

display(img_redimensionada)


#Resultado predicho
if prediccion==0:
  tipo= "BEAGLE"
elif prediccion==2:
  tipo = "PUG"
elif prediccion==1:
  tipo = "OTROS"

tipos=["BEAGLE","OTROS","PUG"]

print("Predicción:", prediccion)
print("Tipo:", tipo)
print("Probabilidades en porcentaje:")
for clase, probabilidad in enumerate(probabilidades_formateadas):
    print(f"Prob {tipos[clase]}: {probabilidad}")

if prediccion==0:
  print(textoB)
elif prediccion==2:
  print(textoP)
elif prediccion==1:
  print("No se tienen los cuidados para esta raza/animal/objeto por el momento")
# Out:
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 32ms/step
# <PIL.Image.Image image mode=RGB size=400x225>
# Predicción: 2
# Tipo: PUG
# Probabilidades en porcentaje:
# Prob BEAGLE: 0.00%
# Prob OTROS: 0.08%
# Prob PUG: 99.91%
#
# Pug cachorro:
# Al cuidar a su perro cuando es un bebé, puede prevenir problemas de salud y comportamiento más adelante, haciendo que sus vidas sean más fáciles.
#
# Necesidades:
# •	Educación: Los Pugs son una raza especialmente testaruda, y cualquiera que sea el comportamiento que estimules como cachorro, se mantendrá hasta la edad adulta.
# •	Higiene: Cada día, limpie suavemente sus pliegues faciales con una almohadilla medicada suave o un hisopo de algodón húmedo y cálido. Esto evita la suciedad y
# las bacterias que pueden causar infecciones o enfermar a su cachorro.
# •	Comedero: Es importante que estén elevados, ya que, cuando se inclinan a tomar agua o a comer, pueden volcarse y esto puede ser muy peligroso.
# •	Temperatura: Son sensibles a la temperatura a cualquier edad, pero cuando son cachorros las temperaturas extremas son un riesgo grave para su salud, pueden tener
# dificultad para respirar en lugares cálidos y fríos y son susceptibles a los resfriados y la neumonía cuando no están protegidos de la intemperie helada. Asegúrate de
# que tenga un suéter que pueda usar cuando la temperatura baje y si hay calor o humedad, mantenlo en un ambiente con temperatura controlada a menos que tenga que hacer
# sus necesidades al aire libre.
# •	Paseos: Camina con tu cachorro poniéndole un arnés en lugar de usar un collar. A causa de sus caras planas, los Pugs pueden presentar dificultad para respirar
# adecuadamente, por lo que los collares tradicionales representan una amenaza para su salud. Los arneses son preferibles para esta raza.
# •	Ejercicio: Deben realizar muchos ejercicios que les permita liberar el estrés y desarrollar sus extremidades. Los primeros años de ejercicios en la vida del Pug
# determinaran los últimos años de este.
#
# Pug adulto:
# El pug tiene el perfecto comportamiento de un perro de compañía, cariñoso, alegre, vivaz, apegado a su familia. Suelen tener una gran tendencia a llamar la atención,
# pero no son excesivamente traviesos.
#
# Necesidades:
# •	Cepillado: Cepillar su pelo una o dos veces por semana, para mantener su pelaje sano y brillante, libre de suciedad y pelos muertos.
# •	Limpieza: Limpia sus arrugas con un paño húmedo y sécalas a conciencia para evitar la aparición de hongos y otras infecciones cutáneas. El aseo de las orejas del
# perro Pug también es esencial. Estamos hablando de perros a los cuales se les acumula suciedad en las orejas con bastante facilidad, por lo menos cada 2 semanas.
# •	Paseos: No debemos exigir a los perros de raza Pug un ejercicio muy intenso. Realiza paseos moderados un par de veces al día, complementados con juegos adecuados
# dentro o fuera de casa son suficientes para satisfacer las necesidades físicas de nuestro perro Pug.
# •	Enfermedades: Conviene destacar su principal problema, el hocico corto, puede afectar negativamente a la salud del Pug. Algunas patologías relacionadas con esto
# son problemas respiratorios, paladar elongado, narinas estenóticas, luxación patelar, entropión y enfermedad de Legg-Calve_perthes. Por otro lado, ocasionalmente
# presentan casos de epilepsia y también lesiones oculares, esto último debido a sus saltones ojos.
#
# Pug senior – anciano:
# Conforme vaya avanzando en su edad podrás apreciar en tu mascota una serie de cambios en su aspecto físico como el cambio en pelaje, se volverá opaco y se caerá
# fácilmente, su piel reseca, el hocico se torna de color gris, disminución de energía general, querrá estar más tiempo dormido, rigidez en sus articulaciones,
# problemas con su dentadura, disminución auditiva gradual y sus ojos con «niebla», disminución visual.
#
# Necesidades:
# •	Hábitos: Trata de mantener sus hábitos en la medida de lo posible, quizá requiera unos ajustes, pero no por ser viejito lo consientas demasiado impidiéndole hacer
# cosas que aun pueda hacer.
# •	Alimentación: Con la edad tu perrito Pug verá afectada su dentadura, tendrá desgaste e incluso perdida de piezas dentales, en consecuencia, a tu Pug le costará
# trabajo masticar sus croquetas duras, un ajuste de dieta será necesario incorporando dieta blanda a su alimentación, claro está recuerda que siempre que realices un
# cambio en su dieta, hazlo gradualmente.
# •	Movilidad: Conforme aumente su edad quizá tengas que hacer paseos más cortos, aunque con mayor frecuencia; también se cansará más rápidamente, así que será
# necesario hacer pequeñas pausas a los paseos. Será recomendable comenzar los paseos a un paso lento, a modo de calentamiento, por unos 10 minutos y luego aumentar el
# ritmo, para finalmente disminuir nuevamente el ritmo hasta volver a casa.
# •	Higiene: Una de las cosas que les pasas con la edad a los Pug es que su piel se reseca, así que no dudes en consultar con tu veterinario para que te recomiende
# alguna crema o suplemento alimenticio que permita mantener su piel en buen estado. Otra situación que ocurre en la piel de los Pug viejitos es que los cuerpos
# pilosos se vuelven más débiles y eso ocasiona que el pelo se le caiga más fácilmente, por lo que sería importante mantener rutina de cepillado, aunque por tiempos
# más cortos, Hacer más esporádico el baño y Mantener hidratada su piel.
# •	Temperatura: Los cambios bruscos de temperatura le pueden afectar, así que procura evitar que tu mascota pase de espacios cálidos a ambientes fríos, sobre todo
# en la temporada invernal.

# %%
#prediccion IMAGEN local
img = ("photo.jpg")
prediccion = categorizarIMG(img)
probabilidades = categorizar1_PIMG(img)
tipo = ""

probabilidades_porcentuales = [p * 100 for p in probabilidades]
probabilidades_formateadas = [f"{p:.2f}%" for p in probabilidades_porcentuales]

# Cargar la imagen capturada
image = Image.open(img)
nuevo_ancho = 400
img_redimensionada = image.resize((nuevo_ancho, int(image.height * (nuevo_ancho / image.width))))

display(img_redimensionada)

#Resultado predicho
if prediccion==0:
  tipo= "BEAGLE"
elif prediccion==2:
  tipo = "PUG"
elif prediccion==1:
  tipo = "OTROS"

tipos=["BEAGLE","OTROS","PUG"]

print("Predicción:", prediccion)
print("Tipo:", tipo)
for clase, probabilidad in enumerate(probabilidades_formateadas):
    print(f"Prob {tipos[clase]}: {probabilidad}")

if prediccion==0:
  print(textoB)
elif prediccion==2:
  print(textoP)
elif prediccion==1:
  print("No se tienen los cuidados para esta raza/animal por el momento")
# Out:
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 0s 24ms/step
# <PIL.Image.Image image mode=RGB size=400x300>
# Predicción: 1
# Tipo: OTROS
# Prob BEAGLE: 36.12%
# Prob OTROS: 51.90%
# Prob PUG: 11.98%
# No se tienen los cuidados para esta raza/animal por el momento

# %%
#Crear la carpeta para exportarla a TF Serving
# !mkdir -p carpeta_salida/modelo_perritos/1

# %%
#Guardar el modelo en formato SavedModel
modelo.save('carpeta_salida/modelo_perritos/1')

# %%
#Hacerlo un zip para bajarlo y usarlo en otro lado
# !zip -r modelo_perritos.zip /content/carpeta_salida/modelo_perritos/

# %%
#Exportar el modelo en formato h5
modelo.save('perritos.h5')

# %%
#Para convertirlo a tensorflow.js, primero debemos instalar la libreria
# !pip install tensorflowjs

# %%
#Crear carpeta donde se colocaran los archivos resultantes
# !mkdir carpeta_salida

# %%
#Realizar la exportacion a la carpeta de salida
# !tensorflowjs_converter --input_format keras perritos.h5 carpeta_salida

# %%
#Confirmar que en la carpeta de salida se hayan generado los archivos. Deben aparecer archivos "bin" y "json"
# !ls carpeta_salida

# %%
#Hacerlo un zip para bajarlo y usarlo en otro lado
# !zip -r modelo_perritos_TrF.zip /content/carpeta_salida/
